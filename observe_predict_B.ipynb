# %% [markdown]
# 本文件中代码仅观察预测数据集，不参与训练和预测流程。

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei'] # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False # 用来正常显示负号
# %matplotlib inline

# %%
for i in range(3):
    predict = pd.read_pickle(f'tmp/predict_B_{i}.pkl')
    for kpi in ['dv1', 'dv2', 'mv1', 'cv1', 'cv2']:
        _ = plt.figure(figsize=(20, 5))
        _ = plt.title(f'{kpi}')
        _ = plt.scatter(predict.time, predict[kpi], s=3, c='b')
        _ = plt.show()

# %%
pd.read_csv('sample_submission_B.csv', encoding='GBK')[:5]
# Out:
#    cv1  cv2  Unnamed: 2 Unnamed: 3
# 0  300  0.5         NaN    第一组数据开始
# 1  300  0.5         NaN        NaN
# 2  300  0.5         NaN        NaN
# 3  300  0.5         NaN        NaN
# 4  300  0.5         NaN        NaN

# %%
pd.read_csv('sample_submission_B.csv', encoding='GBK')[2002:2007]
# Out:
#       cv1  cv2  Unnamed: 2 Unnamed: 3
# 2002  300  0.5         NaN    第二组数据开始
# 2003  300  0.5         NaN        NaN
# 2004  300  0.5         NaN        NaN
# 2005  300  0.5         NaN        NaN
# 2006  300  0.5         NaN        NaN

# %%
pd.read_csv('sample_submission_B.csv', encoding='GBK')[4004:4009]
# Out:
#       cv1  cv2  Unnamed: 2 Unnamed: 3
# 4004  300  0.5         NaN    第三组数据开始
# 4005  300  0.5         NaN        NaN
# 4006  300  0.5         NaN        NaN
# 4007  300  0.5         NaN        NaN
# 4008  300  0.5         NaN        NaN
